# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4) (2.6)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
links=['https://salones-es.lorealprofessionnel.com/ar/santa-fe/rosario']
for i in range(2,9):
    links.append('https://salones-es.lorealprofessionnel.com/ar/santa-fe/rosario?page='+str(i))
len(links)
# Out:
# 8

# %%
links
# Out:
# ['https://salones-es.lorealprofessionnel.com/ar/santa-fe/rosario',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe/rosario?page=2',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe/rosario?page=3',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe/rosario?page=4',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe/rosario?page=5',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe/rosario?page=6',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe/rosario?page=7',
#  'https://salones-es.lorealprofessionnel.com/ar/santa-fe/rosario?page=8']

# %%
direcciones = []
nombres = []

# %%
for i in links:
    url = i
    r = requests.get(url)
    soup = BeautifulSoup(r.content,'html.parser')
    for j in soup.find_all('span',class_="lf-location-default__content__container__header__title__text lf-geo-divisions__top__wrapper__main__locations__list__location__content__container__header__title__text"):
        nombres.append(j.text)
    for k in soup.find_all('span',class_="lf-parts-address__content__street lf-location-default__content__container__address__content__street lf-geo-divisions__top__wrapper__main__locations__list__location__content__container__address__content__street"):
        direcciones.append(k.text)

# %%
direcciones
# Out:
# ['Pje. Mossi 6072',
#  'Tres de Febrero 2398Local 2',
#  'Santa Fe 1780',
#  'Tucumán 1888',
#  'San Juan 825',
#  'Alvear 581',
#  'Sarmiento 585Loc. 31',
#  'Sarmiento 1373Loc. 1',
#  'MENDOZA 5638',
#  'Alberdi 583',
#  '25 De Mayo 250',
#  'Italia 501',
#  'Rioja 654',
#  'Italia 450',
#  'San Lorenzo 743',
#  'San Martín 585',
#  'Mitre 1357',
#  'Larrechea 887',
#  'Provincias Unidas 721 Bis',
#  'Génova 1538',
#  'Remedios de Escalada de San Martín',
#  'Rioja 1072',
#  'Italia 1268',
#  'Salta 1316',
#  'Córdoba 1555Loc. 1° Piso',
#  'Sarmiento 985',
#  'Sarmiento 328',
#  'Mendoza 3692',
#  'Junín 2055',
#  'Juan Domingo Perón 2424',
#  'Mendoza 4236',
#  'Garay 2709',
#  'Rioja 867',
#  'Pje. Álvarez 1524',
#  'Bv. Seguí 1292',
#  'Av. Belgrano 28',
#  'Santiago 748',
#  'Punta Lara 372',
#  'Carballo 220Loc. C',
#  'Mendoza 1563',
#  'Maipú 2366',
#  'Corrientes 1719Dpto. 25',
#  'Mendoza 4236',
#  'Tucumán 1763',
#  'Ricchieri 458',
#  'Gallo 775',
#  'Rioja 1342',
#  'Zeballos 1616P.B. 1',
#  'Libertad 490',
#  '3 de Febrero 1015',
#  'Belgrano 1939',
#  'Santiago 3575',
#  'Belgrano 1275',
#  'Buenos Aires 2369',
#  'Benegas 8842',
#  '12 de Octubre 2280',
#  '3 de Febrero 540',
#  'Iriondo 2151',
#  'Carcaraña 591',
#  'Balcarce 3351',
#  'Juan Manuel de Rosas 2170',
#  '3 de Febrero 2099',
#  'Montevideo 807',
#  'Riobamba 1387',
#  'Montevideo 1088',
#  'Sarmiento 738',
#  '9 de Julio 492',
#  'Pte. Roca 1115',
#  'Laprida 1489',
#  'Catamarca 2246',
#  'Dorrego 2402',
#  'Santa Fe 160',
#  'Lagos 739',
#  'Pasaje Robertson 3393',
#  'Laprida 878',
#  'Balcarce 92 Bis',
#  'Ssan Luis 668',
#  'Mariano Moreno 1301',
#  'Tucumán 210',
#  'Mitre 374',
#  'España 1212',
#  'Laprida 1082',
#  'Mitre 1180',
#  'Fleming 557',
#  'Necochea 1866',
#  'Alem 1723',
#  'Bv. Ocampo 10701º Piso Dpto. 5',
#  '3 de Febrero 278',
#  'Italia 24 Bis',
#  'Angelome 2536',
#  'Sarmiento 1555',
#  'Pueyrredón 868',
#  'Uriburu 1491Loc. 2',
#  'Dorrego 907',
#  'Pueyrredón 1429',
#  'Iriondo 2657',
#  'Mitre y Garibaldi',
#  'Moreno 417Dpto. 1°',
#  'Guatemala 202',
#  'Necochea 422',
#  'Regimiento 11 N° 1117',
#  'Ovidio Lagos 3810Loc. 2',
#  'Presidente Roca 667',
#  'Av. Alberdi 696',
#  'Viamonte 165',
#  'AVDA Genova 1116',
#  'Bv. Oroño 178Bis',
#  'Rivarola 8034',
#  'Av. Alberdi 1029',
#  'Mitre 960Loc. 18',
#  'Paraguay 485',
#  'Mariano Moreno 1167',
#  'Balcarce 223',
#  'Rojas 1437',
#  'Entre Ríos 326',
#  'Santa Fe 54',
#  'Entre Ríos 2513',
#  'Av. Fuerza Aérea 3089Loc. 4',
#  'Ovidio Lagos 1325',
#  'Necochea 1272',
#  'Paraguay 1074',
#  'Tucumán 1622',
#  'Paraguay 643',
#  'San Luis 1971Monoblock',
#  'Elorza 1962',
#  'Bv. Oroño 747',
#  'Av. Brasil 1452',
#  'Italia 1023',
#  'Cafferata 680',
#  'Corrientes 729',
#  'San Luis 1554',
#  'Córdoba 1643Piso 2°',
#  'Sarmiento 1373',
#  'Mitre 1294',
#  'Las Heras 1756',
#  'Corrientes 1958',
#  '3 De Febrero 1191',
#  '50 Nº 715',
#  'Corrientes 1593',
#  '9 De Julio 451',
#  'Mitre 581',
#  'Constitución 655',
#  'San Lorenzo 896',
#  'Mitre 1295',
#  'Montevideo 290',
#  'Mariano Moreno 1436',
#  'PRESIDENTE ROCA 614',
#  'Belgrano 814',
#  'España 1063',
#  'Tucumán 973']

# %%
nombres
# Out:
# ['Stylo Almendra',
#  'Balgias Estilistas',
#  'Tony Barmann Salón de Peinados',
#  'Néstor Tamagna Salón Unisex',
#  'Néstor',
#  'MV Hair',
#  'Matías Baez Peluqueros',
#  'Belén Colombo Estilista',
#  'Ariel y Ana',
#  'Ara Spa',
#  'Algo Distinto',
#  'Yanela',
#  'Walter Peluquerías Beauty & Solarium',
#  'Walter López Hair & Beauty',
#  'Vanina Cinalli',
#  'Tu y Yo Peluquería',
#  'Valenziano Peluquería',
#  'Susana Coiffesse',
#  'Stylo Beauty',
#  'Tortá Peluquerías',
#  'Stella Murua',
#  'Studio C',
#  'Stylo',
#  'Studio Covacevich Salón Exclusivo',
#  'Spazio Sguassero',
#  'Star Femme',
#  'Silvina Lagger Peinados',
#  'Soledad Estilista',
#  'Soledad Brun',
#  'Silvia Tomei',
#  'Silvia y Martín',
#  'Sergio Pintagro Peluquería',
#  'Silver Escuela de Peluquería',
#  'Salvador y Andrés',
#  'Sandel Peluquerías',
#  'Ser Óptimo Peluqueros',
#  'Sebastián López Estilista',
#  'Salón Visagista',
#  "Salón Unisex D'Amato",
#  'Salón S. Rosario',
#  'Salón Edgardo',
#  'Rubén Hair',
#  'S&M Estilo',
#  'Roxana Caro Corte y Estilo',
#  'Roxy',
#  'Rubén Darío Coiffeur',
#  'Ronga',
#  'Rodo Peluquería',
#  'Raquel Castellán Peluquería',
#  "Pon't Guapa Estilistas",
#  'Peluquería Graciela',
#  'Peluquería Graciela',
#  'Peluquería Trinidad',
#  'Peluquería Bety',
#  'Peluquería Gabi',
#  'Peinados Adriana',
#  'Peinados Bibi',
#  'Paty',
#  'Patricia y Sergio Salón Unisex',
#  'Patricia Peluquería',
#  'Patricia Beltrame Unisex',
#  'Pablo y Flavio Peluquería',
#  'Orense Salón Unisex',
#  'Pablo Bilgiarde',
#  'Pablo',
#  'Osiris',
#  'Pablo Giménez',
#  'Nuova Donna',
#  'Pablo Manuzzi Coiffeur',
#  'New Look Hair Design',
#  'Nicolino',
#  'Nilda Borgui Estilista',
#  'Nerina Ottaviano Estilista',
#  'Negrotto Luis Nicolás',
#  'Nico',
#  'Natalia Balerini Peluquería',
#  'Nelson Couffer',
#  'Mundo Pelo',
#  'Nadia Nardi Peluquería',
#  'Mora Peluquería',
#  'Morena',
#  'Miguel Alí',
#  'Mirtha',
#  'Mirta Peinados',
#  'Mirna Guiler Estilista',
#  'Miriam Peluquería',
#  'Martín Vargas',
#  'Marta Peinados',
#  'Mauricio Cordi Peluquería',
#  'Marta Peluquería',
#  'Matías Colman Peluquería y Spa Boutique',
#  'Marilin Peinados',
#  'Mario',
#  'Marina',
#  'Marien Lapple Peluquería',
#  'Maria Virginia Peinados',
#  'Marcia Peinados',
#  'María José Peluquería',
#  'Mabel y Valeria Peluquería',
#  'Lookool Peluquerías',
#  'Leal Daniel',
#  'La Vanguardia',
#  'La Compañía Peluquería',
#  'Kokette Profesional',
#  'Just Dollies',
#  'Juanjo Celma Peluquería',
#  'Isabel Peluquería',
#  'Imag"n',
#  'Hernán Baggi Estilista',
#  'Guappas Peluquería',
#  'Gustavo Cochet Profesional Hair & Make Up',
#  'Graciela Agostinelli',
#  'Glamorosas Salón de Peinados',
#  'Gina Peluquería',
#  'Gisela Bufarini',
#  'Germán Cilfono Estilista',
#  'G&M Peluquería Unisex',
#  'Facelook Peluquería Unisex',
#  'Eclipse Peluquería',
#  'Darío Estilista',
#  'Dante Peluquería',
#  'Croma Peluquería',
#  'Cristian Petrone Peluquería',
#  'Carol',
#  'Cecilia Negrete Peluquería',
#  'Carlos Melo Coiffeur',
#  'Carlos Saavedra Couffer',
#  'Carlos Guirin',
#  'Blassina',
#  'Candela Peluquería',
#  'Beauty Salón',
#  'Beauty La Peluquería',
#  'Belén',
#  'Beauty Center',
#  'Atelier de Teresa Prieto',
#  'B&C Peluquería',
#  'Ariel Parente',
#  'Atelier Noemí',
#  'Ariadna Maricel Salón Unisex',
#  'Ana Peluquería',
#  'Anabela Jaccoud',
#  'Ana María Racca Peluquería',
#  'Ana María Nogues',
#  'Ana Staff',
#  'Ana',
#  'Ale De Melo',
#  'Agustín Prefasio HairStyle Professional',
#  'Alejandra Peluquería',
#  'ACP',
#  'Adrián Manassero y René Manassero']

# %%
dic = {'Nombre':nombres,'Dirección':direcciones}
data = pd.DataFrame(dic)

# %%
data
# Out:
#                                       Nombre                    Dirección
# 0                             Stylo Almendra              Pje. Mossi 6072
# 1                         Balgias Estilistas  Tres de Febrero 2398Local 2
# 2             Tony Barmann Salón de Peinados                Santa Fe 1780
# 3                Néstor Tamagna Salón Unisex                 Tucumán 1888
# 4                                     Néstor                 San Juan 825
# ..                                       ...                          ...
# 145                              Ale De Melo          Mariano Moreno 1436
# 146  Agustín Prefasio HairStyle Professional          PRESIDENTE ROCA 614
# 147                     Alejandra Peluquería                 Belgrano 814
# 148                                      ACP                  España 1063
# 149        Adrián Manassero y René Manassero                  Tucumán 973
#
# [150 rows x 2 columns]
